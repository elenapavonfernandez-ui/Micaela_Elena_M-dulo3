# %% [markdown]
# 1. ¿Existe una diferencia significativa en las tasas de rotación y/o en el nivel de satisfacción laboral en función del género (hombre/mujer) o del estado civil del empleado?
#
#
# 2. ¿Cuál es la relación entre la edad media de los empleados y las tasas de rotación de personal (correlación entre juventud y mayor rotación vs. edad avanzada y estabilidad)?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np # Necesario para crear datos aleatorios

# %%
df = pd.read_csv("df_limpio.csv")
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#    age attrition businesstravel  dailyrate($)                department  \
# 0   51        no            NaN   2015.722222                       NaN
# 1   52        no            NaN   2063.388889                       NaN
# 2   42        no  travel rarely   1984.253968   research & development
# 3   47        no  travel rarely   1771.404762                       NaN
# 4   46        no            NaN   1582.771346                       NaN
#
#    distancefromhome  education    educationfield  employeecount  \
# 0                 6          3               NaN              1
# 1                 1          4     life sciences              1
# 2                 4          2  technical degree              1
# 3                 2          4           medical              1
# 4                 3          3  technical degree              1
#
#    employeenumber  environmentsatisfaction  gender  hourlyrate($)  \
# 0               1                        1       0     251.965278
# ...

# %%
yearsatcompany yearsincurrentrole worklifebalance  

gender maritalstatus


#0 male - 1 female en el proyecto 

#satisfaction: 1 malo - 4 bueno - comprobar rangos. Preguntar Pili. 


#todas las satisfaction son sobre 10?

# %%
df.describe().T
# Out:
#                            count          mean           std           min  \
# age                       1678.0     36.949940      9.155706     18.000000
# dailyrate($)              1678.0    668.079714    470.787298    104.103175
# distancefromhome          1678.0     11.184744     10.479008      1.000000
# education                 1678.0      2.932658      1.024270      1.000000
# employeecount             1678.0      1.000000      0.000000      1.000000
# employeenumber            1678.0    809.859952    467.084867      1.000000
# environmentsatisfaction   1678.0      4.264005      6.912695      1.000000
# gender                    1678.0      0.398689      0.489774      0.000000
# hourlyrate($)             1678.0     83.509964     58.848412     13.012897
# jobinvolvement            1678.0      2.740763      0.710359      1.000000
# joblevel                  1678.0      2.064362      1.099425      1.000000
# ...

# %%
df["environmentsatisfaction"].unique()
# Out:
# array([ 1,  3,  4,  2, 42, 37, 35, 25, 27, 31, 39, 21, 15, 14, 33, 19, 12,
#        13, 28, 47, 36, 29, 24, 46, 16, 22, 41, 49, 11, 48, 18, 10, 45, 38,
#        17, 20, 26, 43])

# %%
df["environmentsatisfaction"].value_counts()

#error de coma. 
#La variable es del 1 al 4. satisfacción 
#Todo lo que tiene dos valores, cuanta solo el primero. 


#education y job level es del 1 al 5
# Out:
# environmentsatisfaction
# 4     483
# 3     471
# 2     316
# 1     306
# 12      7
# 35      7
# 13      6
# 14      6
# 47      5
# 24      5
# 41      4
# 42      4
# 46      4
# 36      4
# 48      4
# 20      3
# 22      3
# 11      3
# 18      3
# 45      3
# 27      3
# 25      3
# 17      3
# 37      2
# 38      2
# 16      2
# 31      2
# 15      2
# 19      2
# 29      2
# 28      1
# 33      1
# 21      1
# 39      1
# 49      1
# 10      1
# 26      1
# 43      1
# Name: count, dtype: int64
