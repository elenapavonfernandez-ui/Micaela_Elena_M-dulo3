# %%
import pandas as pd
import numpy as np

# Visualización
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# Evaluar linealidad de las relaciones entre las variables
# ------------------------------------------------------------------------------
from scipy.stats import shapiro, kstest

# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# Gestión de los warnings
# -----------------------------------------------------------------------
import warnings
warnings.filterwarnings("ignore")

from src import soporte_correlacion as sc

# %%
df_clientes = pd.read_csv("files/clientes.csv")

# %%
df_productos = pd.read_csv("files/productos.csv")

# %%
df_ventas = pd.read_csv("files/ventas.csv")

# %%
df_clientes.head(2)
# Out:
#    id first_name last_name                     email  gender  \
# 0   1      Cheri  Dunsmore  cdunsmore0@instagram.com  Female
# 1   2       Hunt  Bartomeu     hbartomeu1@nsw.gov.au    Male
#
#                 City Country                   Address
# 0  Palma De Mallorca   Spain  076 Rockefeller Crossing
# 1               Lugo   Spain        0046 Utah Junction

# %%
df_productos.head(2)
# Out:
#    ID         Nombre_Producto          Categoría  Precio  Origen  \
# 0  A1        Pizza Margherita  Platos Preparados    8.99  Italia
# 1  B2  Risotto de Champiñones  Platos Preparados    6.75  Italia
#
#                                          Descripción
# 0  Clásica pizza italiana con tomate, mozzarella ...
# 1  Risotto cremoso con champiñones frescos, una d...

# %%
df_ventas.head(2)
# Out:
#    ID_Cliente ID_Producto Fecha_Venta  Cantidad  Total
# 0         723          A1  2023-11-22         2  17.98
# 1         498          C3  2023-11-21         1   5.49

# %%
df_clientes.shape
# Out:
# (1000, 8)

# %%
df_clientes.size
# Out:
# 8000

# %%
df_clientes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1000 non-null   int64
#  1   first_name  1000 non-null   object
#  2   last_name   1000 non-null   object
#  3   email       973 non-null    object
#  4   gender      923 non-null    object
#  5   City        876 non-null    object
#  6   Country     846 non-null    object
#  7   Address     959 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 62.6+ KB

# %%
df_clientes.describe().T
# Out:
#      count   mean         std  min     25%    50%     75%     max
# id  1000.0  500.5  288.819436  1.0  250.75  500.5  750.25  1000.0

# %%
df_clientes.value_counts().sum()
# Out:
# np.int64(641)

# %%
df_clientes.isnull().sum()
# Out:
# id              0
# first_name      0
# last_name       0
# email          27
# gender         77
# City          124
# Country       154
# Address        41
# dtype: int64

# %%
df_clientes.isnull()

# %%
df_clientes.isnull().sum()/df_clientes.shape[0]*100
# Out:
# id             0.0
# first_name     0.0
# last_name      0.0
# email          2.7
# gender         7.7
# City          12.4
# Country       15.4
# Address        4.1
# dtype: float64

# %%
df_clientes.groupby("City").size().sort_values(ascending=False)
# Out:
# City
# Madrid                                      51
# Granada                                     42
# Palma De Mallorca                           41
# Malaga                                      36
# Vitoria-Gasteiz                             32
# Palmas De Gran Canaria, Las                 31
# Pamplona/Iruña                              27
# Valencia                                    27
# Pontevedra                                  24
# Cadiz                                       24
# Sevilla                                     24
# Lleida                                      23
# Santander                                   22
# Valladolid                                  22
# Zamora                                      22
# Donostia-San Sebastian                      21
# Leon                                        20
# Vigo                                        20
# Logroño                                     20
# Albacete                                    20
# ...

# %%
df_clientes.duplicated(subset="City", keep=False).sum()
# Out:
# np.int64(1000)

# %%
df_clientes[df_clientes.duplicated(subset="City", keep=False)].sort_values("City").head(4)
# Out:
#       id first_name last_name                       email       gender  \
# 320  321      Tynan       Oty            toty8w@nymag.com         Male
# 71    72       Niki    Corsor            ncorsor1z@wp.com          NaN
# 248  249     Aloise  McKillop      amckillop6w@sfgate.com  Genderqueer
# 373  374   Dominica     Aslum  daslumad@ezinearticles.com       Female
#
#          City Country                Address
# 320  Albacete     NaN    02 Reindahl Terrace
# 71   Albacete   Spain          91 Vidon Pass
# 248  Albacete   Spain  47138 Fieldstone Road
# 373  Albacete   Spain       3 Armistice Lane

# %%
df_clientes["email"].duplicated().sum() #Hay 0 ID duplicados, pero tenemos 26 emails duplicados
# Out:
# np.int64(26)

# %% [markdown]
# crear función
